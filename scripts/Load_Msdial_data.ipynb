# %%
from matchms.exporting import save_as_mgf
from core.external import load_MS_DIAL_Alginment

# %%
spectrums = load_MS_DIAL_Alginment('example/MS_DIAL_example.txt')
# Out:
# D:\DeepMASS2_GUI\core\external.py:94: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   data = pd.read_csv(filename, '\t')
# 100%|█████████████████████████████████████████████████████████████████████████████| 3236/3236 [00:04<00:00, 729.35it/s]

# %%
spectrums[0].plot()
# Out:
# (<Figure size 1600x1200 with 1 Axes>,
#  <Axes: title={'center': 'Spectrum'}, xlabel='m/z', ylabel='Intensity'>)

# %%
save_as_mgf(spectrums, 'example/MS_DIAL_example.mgf')
# Out:
# C:\Users\DELL\anaconda3\envs\deepmass\lib\site-packages\pyteomics\mgf.py:776: UserWarning: Passing a single spectrum to `write()` is discouraged. To write a set of spectra, pass them to `write()` all at once. For more info, see: https://github.com/levitsky/pyteomics/discussions/109.
#   warnings.warn("Passing a single spectrum to `write()` is discouraged. "
